# %% [markdown]
# This first block of text simply contains all the libraries that need importing as well as initialising some variables of this example. You may change the batch_size and epochs variables, but should not change num_classes, img_rows and img_cols as these depend on the dataset being used

# %%
from __future__ import print_function
import tensorflow.keras as keras
import tensorflow.keras.datasets as datasets
from tensorflow.keras import models
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras import backend as K
from matplotlib import pyplot as plt
from tensorflow.keras.applications.vgg16 import VGG16

batch_size = 256
num_classes = 10
epochs = 20

# input image dimensions
img_rows, img_cols = 32, 32

# list of optimizers
optimizers = ['SGD', 'Adam', 'Adadelta', 'Adagrad', 'Adamax']

# %% [markdown]
# The next block of text handles all the data loading (in this case of the CIFAR-10 dataset) and reshaping so that it can be used to train and evaluate the CNN models. Two sets of data are loaded, the training data, used to generate the model, and the test data, used to evaluate if this model is good at making predictions

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 3, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 3, img_rows, img_cols)
    input_shape = (3, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 3)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test_orig = y_test
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# This cell loads given pre-defined architecture, that had been trained for a different problem. It removes the last layer (because that would be specific to the original problem, and adds some new layers. This process of adapting a network trained on a different problem is called *Transfer Learning*.
#
# The only essential new layer to add is the softmax one (last) that specifies the number of classes of the new dataset.

# %%
def get_model(optimizer):
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
    # add a global spatial average pooling layer
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    # let's add a fully-connected layer
    x = Dense(1024, activation='relu')(x)
    # and a logistic layer -- let's say we have 200 classes
    predictions = Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs=base_model.input, outputs=predictions)

    # The rest of this cell is common to both defining the full architecture or using a pre-trained one
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=optimizer,
                  metrics=['accuracy'])

    return model

# %% [markdown]
# This is the block of code that trains models and evaluates their predictive capacity on the test data.

# %%
train_acc, val_acc = ([] for i in range(2))

for optimizer in optimizers:
    # Create model
    model = get_model(optimizer)

    history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test),
          verbose=1)

    # Save results
    train_acc.append(history.history['accuracy'])
    val_acc.append(history.history['val_accuracy'])

    # Evaluate the model on the test data
    test_loss, test_acc =  model.evaluate(x_test, y_test,
              batch_size=batch_size,
              verbose=0)

    # Display the final accuracy and loss of the CNN architecture
    print('Optimizer: ', optimizer, ', Accuracy: %.2f%%' % (test_acc * 100), ', Loss: %.2f' % test_loss)
    print()
# Out:
# Epoch 1/20
# 196/196 [==============================] - 47s 208ms/step - loss: 1.8636 - accuracy: 0.3527 - val_loss: 1.0572 - val_accuracy: 0.6460
# Epoch 2/20
# 196/196 [==============================] - 38s 196ms/step - loss: 0.9965 - accuracy: 0.6552 - val_loss: 0.7941 - val_accuracy: 0.7209
# Epoch 3/20
# 196/196 [==============================] - 38s 196ms/step - loss: 0.7538 - accuracy: 0.7392 - val_loss: 0.8132 - val_accuracy: 0.7192
# Epoch 4/20
# 196/196 [==============================] - 38s 196ms/step - loss: 0.6644 - accuracy: 0.7715 - val_loss: 0.6401 - val_accuracy: 0.7748
# Epoch 5/20
# 196/196 [==============================] - 38s 196ms/step - loss: 0.5814 - accuracy: 0.7981 - val_loss: 0.6123 - val_accuracy: 0.7900
# Epoch 6/20
# 196/196 [==============================] - 38s 195ms/step - loss: 0.5069 - accuracy: 0.8254 - val_loss: 0.8041 - val_accuracy: 0.7300
# Epoch 7/20
# 196/196 [==============================] - 38s 195ms/step - loss: 0.4787 - accuracy: 0.8342 - val_loss: 0.5520 - val_accuracy: 0.8116
# Epoch 8/20
# 196/196 [==============================] - 38s 196ms/step - loss: 0
20
# 196/196 [==============================] - 39s 199ms/step - loss: 0.6990 - accuracy: 0.7551 - val_loss: 0.7793 - val_accuracy: 0.7268
# Epoch 20/20
# 196/196 [==============================] - 39s 199ms/step - loss: 0.7106 - accuracy: 0.7531 - val_loss: 0.7495 - val_accuracy: 0.7393
# Optimizer:  Adadelta , Accuracy: 73.93% , Loss: 0.75
#
# Epoch 1/20
# 196/196 [==============================] - 40s 199ms/step - loss: 1.8853 - accuracy: 0.3346 - val_loss: 1.1173 - val_accuracy: 0.6099
# Epoch 2/20
# 196/196 [==============================] - 38s 196ms/step - loss: 1.0361 - accuracy: 0.6445 - val_loss: 0.9309 - val_accuracy: 0.6782
# Epoch 3/20
# 196/196 [==============================] - 38s 196ms/step - loss: 0.8632 - accuracy: 0.6995 - val_loss: 1.0919 - val_accuracy: 0.6188
# Epoch 4/20
# 196/196 [==============================] - 38s 196ms/step - loss: 0.7600 - accuracy: 0.7354 - val_loss: 0.7742 - val_accuracy: 0.7289
# Epoch 5/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.6884 - accuracy: 0.7611 - val_loss: 0.6848 - val_accuracy: 0.7608
# Epoch 6/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.6319 - accuracy: 0.7798 - val_loss: 0.8073 - val_accuracy: 0.7193
# Epoch 7/20
# 196/196 [==============================] - 38s 196ms/step - loss: 0.5981 - accuracy: 0.7905 - val_loss: 0.7794 - val_accuracy: 0.7380
# Epoch 8/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.5571 - accuracy: 0.8063 - val_loss: 0.6211 - val_accuracy: 0.7824
# Epoch 9/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.5296 - accuracy: 0.8151 - val_loss: 0.7822 - val_accuracy: 0.7297
# Epoch 10/20
# 196/196 [==============================] - 38s 196ms/step - loss: 0.5177 - accuracy: 0.8192 - val_loss: 0.5984 - val_accuracy: 0.7916
# Epoch 11/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.4867 - accuracy: 0.8286 - val_loss: 0.5951 - val_accuracy: 0.7938
# Epoch 12/20
# 196/196 [==============================] - 38s 196ms/step - loss: 0.4620 - accuracy: 0.8387 - val_loss: 0.6090 - val_accuracy: 0.7918
# Epoch 13/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.4543 - accuracy: 0.8431 - val_loss: 0.6635 - val_accuracy: 0.7710
# Epoch 14/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.4372 - accuracy: 0.8472 - val_loss: 0.7172 - val_accuracy: 0.7572
# Epoch 15/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.4148 - accuracy: 0.8558 - val_loss: 0.6460 - val_accuracy: 0.7754
# Epoch 16/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.4029 - accuracy: 0.8595 - val_loss: 0.5867 - val_accuracy: 0.7978
# Epoch 17/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.3718 - accuracy: 0.8725 - val_loss: 0.7090 - val_accuracy: 0.7685
# Epoch 18/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.3752 - accuracy: 0.8701 - val_loss: 0.5867 - val_accuracy: 0.7993
# Epoch 19/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.3552 - accuracy: 0.8792 - val_loss: 0.7923 - val_accuracy: 0.7571
# Epoch 20/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.3471 - accuracy: 0.8796 - val_loss: 0.5242 - val_accuracy: 0.8224
# Optimizer:  Adagrad , Accuracy: 82.24% , Loss: 0.52
#
# Epoch 1/20
# 196/196 [==============================] - 40s 199ms/step - loss: 2.0548 - accuracy: 0.1982 - val_loss: 1.4128 - val_accuracy: 0.4842
# Epoch 2/20
# 196/196 [==============================] - 39s 198ms/step - loss: 1.1175 - accuracy: 0.5873 - val_loss: 0.8264 - val_accuracy: 0.7210
# Epoch 3/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.7070 - accuracy: 0.7554 - val_loss: 0.7768 - val_accuracy: 0.7408
# Epoch 4/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.5471 - accuracy: 0.8110 - val_loss: 0.6694 - val_accuracy: 0.7811
# Epoch 5/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.4199 - accuracy: 0.8597 - val_loss: 0.5660 - val_accuracy: 0.8092
# Epoch 6/20
# 196/196 [==============================] - 39s 198ms/step - loss: 0.3129 - accuracy: 0.8945 - val_loss: 0.5453 - val_accuracy: 0.8283
# Epoch 7/20
# 196/196 [==============================] - 39s 198ms/step - loss: 0.2396 - accuracy: 0.9180 - val_loss: 0.5456 - val_accuracy: 0.8338
# Epoch 8/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.1826 - accuracy: 0.9395 - val_loss: 0.5613 - val_accuracy: 0.8421
# Epoch 9/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.1367 - accuracy: 0.9533 - val_loss: 0.5790 - val_accuracy: 0.8403
# Epoch 10/20
# 196/196 [==============================] - 39s 198ms/step - loss: 0.1056 - accuracy: 0.9655 - val_loss: 0.5922 - val_accuracy: 0.8462
# Epoch 11/20
# 196/196 [==============================] - 39s 198ms/step - loss: 0.0773 - accuracy: 0.9750 - val_loss: 0.6405 - val_accuracy: 0.8426
# Epoch 12/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.0798 - accuracy: 0.9746 - val_loss: 0.6222 - val_accuracy: 0.8526
# Epoch 13/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.0462 - accuracy: 0.9850 - val_loss: 0.9343 - val_accuracy: 0.8141
# Epoch 14/20
# 196/196 [==============================] - 39s 198ms/step - loss: 0.0630 - accuracy: 0.9790 - val_loss: 0.7235 - val_accuracy: 0.8402
# Epoch 15/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.0444 - accuracy: 0.9865 - val_loss: 0.7226 - val_accuracy: 0.8538
# Epoch 16/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.0342 - accuracy: 0.9882 - val_loss: 0.7398 - val_accuracy: 0.8494
# Epoch 17/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.0307 - accuracy: 0.9903 - val_loss: 0.7380 - val_accuracy: 0.8509
# Epoch 18/20
# 196/196 [==============================] - 39s 198ms/step - loss: 0.0223 - accuracy: 0.9927 - val_loss: 0.7523 - val_accuracy: 0.8454
# Epoch 19/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.0335 - accuracy: 0.9892 - val_loss: 0.8127 - val_accuracy: 0.8446
# Epoch 20/20
# 196/196 [==============================] - 39s 197ms/step - loss: 0.0312 - accuracy: 0.9899 - val_loss: 0.7145 - val_accuracy: 0.8569
# Optimizer:  Adamax , Accuracy: 85.69% , Loss: 0.71

# %% [markdown]
# Finally, plots of how the training & validation accuracy functions changes through the epochs of training is shown.

# %%
# Display Training Accuracy plot graph
plt.figure(figsize=(10,7))
for history in train_acc:
  plt.plot(history)
plt.title('Training Accuracy of Optimizers')
plt.ylabel('Training Accuracy')
plt.xlabel('Epoch')
plt.legend(optimizers)
plt.ylim(0, 1)
plt.savefig('Optimizers-training-accuracy-comparison.jpg', dpi=200)
plt.show()
print()

# Display Validation Accuracy plot graph
plt.figure(figsize=(10,7))
for history in val_acc:
  plt.plot(history)
plt.title('Validation Accuracy of Optimizers')
plt.ylabel('Validation Accuracy')
plt.xlabel('Epoch')
plt.legend(optimizers)
plt.ylim(0, 1)
plt.savefig('Optimizers-validation-accuracy-comparison.jpg', dpi=200)
plt.show()
